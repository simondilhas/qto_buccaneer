# %%
import pandas as pd
import json
from qto_buccaneer.utils._config_loader import load_config
from pathlib import Path
import os
from qto_buccaneer._utils.calculate.exp_data.metadata_filter_exp import MetadataFilter

# %%
file_path = "exp_data/ifc_model_metadata.json"

# First read the JSON file as a Python dictionary
with open(file_path, 'r') as f:
    data = json.load(f)

# Access the elements dictionary and convert to DataFrame
elements_df = pd.DataFrame.from_dict(data['elements'], orient='index')
elements_df.head()
# Out:
#    id  parent_id                GlobalId    IfcEntity Classifications Systems  \
# 1   1        NaN  21MDAeADb9799Web$9RSGv   IfcProject              []      []
# 2   2      166.0  02elX7_Bn8iOvJoCquoGkE  IfcCovering              []      []
# 3   3      166.0  0yYm8GUG91FwVoYIMqgbFo  IfcCovering              []      []
# 4   4      166.0  3nEtufSFj7bwK99Y7Xt8xx  IfcCovering              []      []
# 5   5      164.0  0tkgbUMcT25OBOhCgbQt78  IfcCovering              []      []
#
#               Name ConnectedFrom ConnectedTo      ContainedInStructure  ...  \
# 1  Mustermodell V1           NaN         NaN                       NaN  ...
# 2         CLADDING            []          []  [2h36Exz$16SQJ6pcny43V3]  ...
# 3         CLADDING            []          []  [2h36Exz$16SQJ6pcny43V3]  ...
# 4         CLADDING            []          []  [2h36Exz$16SQJ6pcny43V3]  ...
# 5         FLOORING            []          []  [3_tSJLGEDBgPkOwRkkHz8p]  ...
#
#   Pset_Enrichment.EBF ePset_abstractBIM.ClassificationSIA416  \
# 1                 NaN                                    NaN
# 2                 NaN                                    NaN
# 3                 NaN                                    NaN
# 4                 NaN                                    NaN
# 5                 NaN                                    NaN
#
#   ePset_abstractBIM.OriginalClassificationSIA ePset_abstractBIM.OriginalGUIDS  \
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
# 5                                         NaN                             NaN
#
#   Qto_SpaceBaseQuantities.Height Qto_SpaceBaseQuantities.Perimeter  \
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
# 5                            NaN                               NaN
#
#   Qto_SpaceBaseQuantities.NetFloorArea Qto_SpaceBaseQuantities.NetVolume  \
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# 5                                  NaN                               NaN
#
#   Pset_Enrichment.m2 Pset_Enrichment.RFB Nr.
# 1                NaN                     NaN
# 2                NaN                     NaN
# 3                NaN                     NaN
# 4                NaN                     NaN
# 5                NaN                     NaN
#
# [5 rows x 83 columns]

# %%
config_path = Path("exp_data") / "00_workflow_config.yaml"
config = load_config(config_path)

metrics_config = config.get("metrics")
gf_gesamt_config = metrics_config.get("gf_gesamt")
print(gf_gesamt_config)
# Out:
# {'name': 'GF Gesamt', 'description': 'Die Gesamte Geschossfläche, durch die abstraction sind die Aussenwände mit einer Dicke von 35cm berechnet.', 'config': {'quantity_type': 'area', 'unit': 'm2', 'formula': 'GF - LUF', 'components': {'GF': {'filter': 'IfcEntity=IfcSpace AND Name=GrossArea', 'base_quantity': 'Qto_SpaceBaseQuantities.NetFloorArea'}, 'LUF': {'filter': 'IfcEntity=IfcSpace AND LongName=LUF', 'base_quantity': 'Qto_SpaceBaseQuantities.NetFloorArea'}}}}

# %%
def calculate_metric(df: pd.DataFrame, metric_config: dict, building: str) -> pd.DataFrame:
    """
    Calculate a metric based on the provided configuration.
    
    Args:
        df: DataFrame containing the IFC model data
        metric_config: Dictionary containing metric configuration
        building: Name of the building
        
    Returns:
        DataFrame with metric results
    """
    import time
    start_time = time.time()
    
    # Check if this is a formula-based calculation
    if 'formula' in metric_config['config']:
        # Calculate each component
        component_values = {}
        for component_name, component_config in metric_config['config']['components'].items():
            # Filter the DataFrame for this component
            filtered_df = MetadataFilter.filter_df_from_str(df, component_config['filter'])
            # Calculate the sum of the specified quantity
            component_values[component_name] = filtered_df[component_config['base_quantity']].sum()
        
        # Evaluate the formula
        formula = metric_config['config']['formula']
        # Replace component names with their values
        for component_name, value in component_values.items():
            formula = formula.replace(component_name, str(value))
        # Evaluate the formula safely
        try:
            value = eval(formula)
        except Exception as e:
            raise ValueError(f"Error evaluating formula '{formula}': {str(e)}")
    else:
        # Original simple calculation
        filtered_df = MetadataFilter.filter_df_from_str(df, metric_config['config']['filter'])
        value = filtered_df[metric_config['config']['base_quantity']].sum()
    
    # Create result DataFrame
    result = pd.DataFrame({
        'metric_name': [metric_config['name']],
        'value': [value],
        'unit': [metric_config['config']['unit']],
        'success': [True],
        'calculation_time': [time.time() - start_time],
        'building': [building]
    })
    
    return result

# Example usage:
metric_result = calculate_metric(elements_df, gf_gesamt_config, "Example Building")
metric_result
# Out:
# Parsing filter string: IfcEntity=IfcSpace AND Name=GrossArea
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: Name=GrossArea
# Parsed term - key: Name, op: =, val: GrossArea
# Final filters: {'IfcEntity': 'IfcSpace', 'Name': 'GrossArea'}
# Parsing filter string: IfcEntity=IfcSpace AND LongName=LUF
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: LongName=LUF
# Parsed term - key: LongName, op: =, val: LUF
# Final filters: {'IfcEntity': 'IfcSpace', 'LongName': 'LUF'}
#   metric_name      value unit  success  calculation_time          building
# 0   GF Gesamt  194.41235   m2     True          0.005161  Example Building

# %%
# Initialize an empty list to store all metric results
all_results = []

# Calculate all metrics and accumulate results
for metric_name, metric_config in metrics_config.items():
    metric_result = calculate_metric(elements_df, metric_config, "Example Building")
    all_results.append(metric_result)

# Combine all results into a single DataFrame
combined_results = pd.concat(all_results, ignore_index=True)
combined_results
# Out:
# Parsing filter string: IfcEntity=IfcSpace AND PredefinedType=INTERNAL AND Pset_Enrichment.SiA-2016=HNF
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: PredefinedType=INTERNAL
# Parsed term - key: PredefinedType, op: =, val: INTERNAL
# Processing part: Pset_Enrichment.SiA-2016=HNF
# Parsed term - key: Pset_Enrichment.SiA-2016, op: =, val: HNF
# Final filters: {'IfcEntity': 'IfcSpace', 'PredefinedType': 'INTERNAL', 'Pset_Enrichment.SiA-2016': 'HNF'}
# Parsing filter string: IfcEntity=IfcSpace AND PredefinedType=INTERNAL AND Pset_Enrichment.SiA-2016=NNF
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: PredefinedType=INTERNAL
# Parsed term - key: PredefinedType, op: =, val: INTERNAL
# Processing part: Pset_Enrichment.SiA-2016=NNF
# Parsed term - key: Pset_Enrichment.SiA-2016, op: =, val: NNF
# Final filters: {'IfcEntity': 'IfcSpace', 'PredefinedType': 'INTERNAL', 'Pset_Enrichment.SiA-2016': 'NNF'}
# Parsing filter string: IfcEntity=IfcSpace AND PredefinedType=INTERNAL AND Pset_Enrichment.SiA-2016=VF
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: PredefinedType=INTERNAL
# Parsed term - key: PredefinedType, op: =, val: INTERNAL
# Processing part: Pset_Enrichment.SiA-2016=VF
# Parsed term - key: Pset_Enrichment.SiA-2016, op: =, val: VF
# Final filters: {'IfcEntity': 'IfcSpace', 'PredefinedType': 'INTERNAL', 'Pset_Enrichment.SiA-2016': 'VF'}
# Parsing filter string: IfcEntity=IfcSpace AND PredefinedType=INTERNAL AND Pset_Enrichment.SiA-2016=FF
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: PredefinedType=INTERNAL
# Parsed term - key: PredefinedType, op: =, val: INTERNAL
# Processing part: Pset_Enrichment.SiA-2016=FF
# Parsed term - key: Pset_Enrichment.SiA-2016, op: =, val: FF
# Final filters: {'IfcEntity': 'IfcSpace', 'PredefinedType': 'INTERNAL', 'Pset_Enrichment.SiA-2016': 'FF'}
# Parsing filter string: IfcEntity=IfcSpace AND Name=GrossArea
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: Name=GrossArea
# Parsed term - key: Name, op: =, val: GrossArea
# Final filters: {'IfcEntity': 'IfcSpace', 'Name': 'GrossArea'}
# Parsing filter string: IfcEntity=IfcSpace AND LongName=LUF
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: LongName=LUF
# Parsed term - key: LongName, op: =, val: LUF
# Final filters: {'IfcEntity': 'IfcSpace', 'LongName': 'LUF'}
# Parsing filter string: IfcEntity=IfcSpace AND Name=GrossArea
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: Name=GrossArea
# Parsed term - key: Name, op: =, val: GrossArea
# Final filters: {'IfcEntity': 'IfcSpace', 'Name': 'GrossArea'}
# Parsing filter string: IfcEntity=IfcSpace AND PredefinedType=INTERNAL
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: PredefinedType=INTERNAL
# Parsed term - key: PredefinedType, op: =, val: INTERNAL
# Final filters: {'IfcEntity': 'IfcSpace', 'PredefinedType': 'INTERNAL'}
# Parsing filter string: IfcEntity=IfcSpace AND Name=GrossArea
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: Name=GrossArea
# Parsed term - key: Name, op: =, val: GrossArea
# Final filters: {'IfcEntity': 'IfcSpace', 'Name': 'GrossArea'}
# Parsing filter string: IfcEntity=IfcSpace AND PredefinedType=INTERNAL
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: PredefinedType=INTERNAL
# Parsed term - key: PredefinedType, op: =, val: INTERNAL
# Final filters: {'IfcEntity': 'IfcSpace', 'PredefinedType': 'INTERNAL'}
# Parsing filter string: IfcEntity=IfcSpace AND Name=GrossArea AND Pset_SpatialData.ElevationOfStory<=0.5
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: Name=GrossArea
# Parsed term - key: Name, op: =, val: GrossArea
# Processing part: Pset_SpatialData.ElevationOfStory<=0.5
# Parsed term - key: Pset_SpatialData.ElevationOfStory, op: <=, val: 0.5
# Final filters: {'IfcEntity': 'IfcSpace', 'Name': 'GrossArea', 'Pset_SpatialData.ElevationOfStory': [('<=', 0.5)]}
# Parsing filter string: IfcEntity=IfcSpace AND LongName=LUF AND Pset_SpatialData.ElevationOfStory<=0.5
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: LongName=LUF
# Parsed term - key: LongName, op: =, val: LUF
# Processing part: Pset_SpatialData.ElevationOfStory<=0.5
# Parsed term - key: Pset_SpatialData.ElevationOfStory, op: <=, val: 0.5
# Final filters: {'IfcEntity': 'IfcSpace', 'LongName': 'LUF', 'Pset_SpatialData.ElevationOfStory': [('<=', 0.5)]}
# Parsing filter string: IfcEntity=IfcSpace AND Name=GrossArea AND Pset_SpatialData.ElevationOfStory>0.5
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: Name=GrossArea
# Parsed term - key: Name, op: =, val: GrossArea
# Processing part: Pset_SpatialData.ElevationOfStory>0.5
# Parsed term - key: Pset_SpatialData.ElevationOfStory, op: >, val: 0.5
# Final filters: {'IfcEntity': 'IfcSpace', 'Name': 'GrossArea', 'Pset_SpatialData.ElevationOfStory': [('>', 0.5)]}
# Parsing filter string: IfcEntity=IfcSpace AND LongName=LUF AND Pset_SpatialData.ElevationOfStory>0.5
# Processing part: IfcEntity=IfcSpace
# Parsed term - key: IfcEntity, op: =, val: IfcSpace
# Processing part: LongName=LUF
# Parsed term - key: LongName, op: =, val: LUF
# Processing part: Pset_SpatialData.ElevationOfStory>0.5
# Parsed term - key: Pset_SpatialData.ElevationOfStory, op: >, val: 0.5
# Final filters: {'IfcEntity': 'IfcSpace', 'LongName': 'LUF', 'Pset_SpatialData.ElevationOfStory': [('>', 0.5)]}
#                      metric_name       value unit  success  calculation_time  \
# 0                      HNF Total   55.218750   m2     True          0.002587
# 1                      NNF Total   40.000000   m2     True          0.002301
# 2       VF Verkehrsfläche Neubau   11.625000   m2     True          0.001683
# 3  FF Funktionsfläche Neubau: m2    0.000000   m2     True          0.001548
# 4                      GF Gesamt  194.412350   m2     True          0.002763
# 5              % Anteil KF an GF   18.597769    %     True          0.002715
# 6   KF Konstruktionsfläche Total   38.318350   m2     True          0.002174
# 7                   GF oi Neubau  139.916100   m2     True          0.002672
# 8                   GF ui Neubau   54.496250   m2     True          0.002501
#
#            building
# 0  Example Building
# 1  Example Building
# 2  Example Building
# 3  Example Building
# 4  Example Building
# 5  Example Building
# 6  Example Building
# 7  Example Building
# 8  Example Building
