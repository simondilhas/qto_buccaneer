# %%
import pandas as pd
import json
from qto_buccaneer.utils._config_loader import load_config
from pathlib import Path
import os
from qto_buccaneer._utils.calculate.exp_data.metadata_filter_exp import MetadataFilter

# %%
file_path = "exp_data/ifc_model_metadata.json"

# First read the JSON file as a Python dictionary
with open(file_path, 'r') as f:
    data = json.load(f)

# Access the elements dictionary and convert to DataFrame
elements_df = pd.DataFrame.from_dict(data['elements'], orient='index')
elements_df.head()
# Out:
#    id  parent_id                GlobalId    IfcEntity Classifications Systems  \
# 1   1        NaN  21MDAeADb9799Web$9RSGv   IfcProject              []      []
# 2   2      166.0  02elX7_Bn8iOvJoCquoGkE  IfcCovering              []      []
# 3   3      166.0  0yYm8GUG91FwVoYIMqgbFo  IfcCovering              []      []
# 4   4      166.0  3nEtufSFj7bwK99Y7Xt8xx  IfcCovering              []      []
# 5   5      164.0  0tkgbUMcT25OBOhCgbQt78  IfcCovering              []      []
#
#               Name ConnectedFrom ConnectedTo      ContainedInStructure  ...  \
# 1  Mustermodell V1           NaN         NaN                       NaN  ...
# 2         CLADDING            []          []  [2h36Exz$16SQJ6pcny43V3]  ...
# 3         CLADDING            []          []  [2h36Exz$16SQJ6pcny43V3]  ...
# 4         CLADDING            []          []  [2h36Exz$16SQJ6pcny43V3]  ...
# 5         FLOORING            []          []  [3_tSJLGEDBgPkOwRkkHz8p]  ...
#
#   Pset_Enrichment.EBF ePset_abstractBIM.ClassificationSIA416  \
# 1                 NaN                                    NaN
# 2                 NaN                                    NaN
# 3                 NaN                                    NaN
# 4                 NaN                                    NaN
# 5                 NaN                                    NaN
#
#   ePset_abstractBIM.OriginalClassificationSIA ePset_abstractBIM.OriginalGUIDS  \
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
# 5                                         NaN                             NaN
#
#   Qto_SpaceBaseQuantities.Height Qto_SpaceBaseQuantities.Perimeter  \
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
# 5                            NaN                               NaN
#
#   Qto_SpaceBaseQuantities.NetFloorArea Qto_SpaceBaseQuantities.NetVolume  \
# 1                                  NaN                               NaN
# 2                                  NaN                               NaN
# 3                                  NaN                               NaN
# 4                                  NaN                               NaN
# 5                                  NaN                               NaN
#
#   Pset_Enrichment.m2 Pset_Enrichment.RFB Nr.
# 1                NaN                     NaN
# 2                NaN                     NaN
# 3                NaN                     NaN
# 4                NaN                     NaN
# 5                NaN                     NaN
#
# [5 rows x 83 columns]

# %%
config_path = Path("exp_data") / "00_workflow_config.yaml"
config = load_config(config_path)

metrics_config = config.get("metrics")
gf_gesamt_config = metrics_config.get("gf_gesamt")
print(gf_gesamt_config)
# Out:
# {'name': 'GF Gesamt', 'description': 'Die Gesamte Geschossfläche, durch die abstraction sind die Aussenwände mit einer Dicke von 35cm berechnet.', 'config': {'quantity_type': 'area', 'unit': 'm2', 'formula': 'GF - LUF', 'components': {'GF': {'filter': 'IfcEntity=IfcSpace AND Name=GrossArea', 'base_quantity': 'Qto_SpaceBaseQuantities.NetFloorArea'}, 'LUF': {'filter': 'IfcEntity=IfcSpace AND LongName=LUF', 'base_quantity': 'Qto_SpaceBaseQuantities.NetFloorArea'}}}}

# %%
def calculate_metric(df: pd.DataFrame, metric_config: dict, building: str) -> pd.DataFrame:
    """
    Calculate a metric based on the provided configuration.
    
    Args:
        df: DataFrame containing the IFC model data
        metric_config: Dictionary containing metric configuration
        building: Name of the building
        
    Returns:
        DataFrame with metric results
    """
    import time
    start_time = time.time()
    
    # Check if this is a formula-based calculation
    if 'formula' in metric_config['config']:
        # Calculate each component
        component_values = {}
        for component_name, component_config in metric_config['config']['components'].items():
            # Filter the DataFrame for this component
            filtered_df = MetadataFilter.filter_df_from_str(df, component_config['filter'])
            # Calculate the sum of the specified quantity
            component_values[component_name] = filtered_df[component_config['base_quantity']].sum()
        
        # Evaluate the formula
        formula = metric_config['config']['formula']
        # Replace component names with their values
        for component_name, value in component_values.items():
            formula = formula.replace(component_name, str(value))
        # Evaluate the formula safely
        try:
            value = eval(formula)
        except Exception as e:
            raise ValueError(f"Error evaluating formula '{formula}': {str(e)}")
    else:
        # Original simple calculation
        filtered_df = MetadataFilter.filter_df_from_str(df, metric_config['config']['filter'])
        value = filtered_df[metric_config['config']['base_quantity']].sum()
    
    # Create result DataFrame
    result = pd.DataFrame({
        'metric_name': [metric_config['name']],
        'value': [value],
        'unit': [metric_config['config']['unit']],
        'success': [True],
        'calculation_time': [time.time() - start_time],
        'building': [building],
        'description': [metric_config['description']],
        'formula': [metric_config['config']['formula']],
        'components': str([metric_config['config']['components']])

    })  
    
    return result

# Example usage:
metric_result = calculate_metric(elements_df, gf_gesamt_config, "Example Building")
metric_result
# Out:
#   metric_name      value unit  success  calculation_time          building  \
# 0   GF Gesamt  194.41235   m2     True           0.00453  Example Building
#
#                                          description   formula  \
# 0  Die Gesamte Geschossfläche, durch die abstract...  GF - LUF
#
#                                           components
# 0  [{'GF': {'filter': 'IfcEntity=IfcSpace AND Nam...

# %%
# Initialize an empty list to store all metric results
all_results = []

# Calculate all metrics and accumulate results
for metric_name, metric_config in metrics_config.items():
    metric_result = calculate_metric(elements_df, metric_config, "Example Building")
    all_results.append(metric_result)

# Combine all results into a single DataFrame
combined_results = pd.concat(all_results, ignore_index=True)
combined_results
# Out:
#                            metric_name       value unit  success  \
# 0                            HNF Total   55.218750   m2     True
# 1                            NNF Total   40.000000   m2     True
# 2             VF Verkehrsfläche Neubau   11.625000   m2     True
# 3        FF Funktionsfläche Neubau: m2    0.000000   m2     True
# 4                            GF Gesamt  194.412350   m2     True
# 5                    % Anteil KF an GF   18.597769    %     True
# 6         KF Konstruktionsfläche Total   38.318350   m2     True
# 7                         GF oi Neubau  128.291100   m2     True
# 8                         GF ui Neubau   66.121250   m2     True
# 9                         GV Neubau oi  452.335680   m3     True
# 10                        GV ui Neubau  257.872875   m3     True
# 11                           Hilfe EBF   55.218750   m2     True
# 12                                 EBF  139.193600   m2     True
# 13                                 FBF   73.794850   m2     True
# 14  E1 Fläche Aussenwand unter Terrain  113.794940   m2     True
# 15   E2 Fläche Aussenwand über Terrain  249.956384   m2     True
# 16   E3 Fläche Einbauten zu Aussenwand    8.210200   m2     True
# 17          E2.5 Bekleidung Untersicht   32.847350   m2     True
# 18                         Dachflächen   73.794850   m2     True
# 19                                 AGF    0.000000   m2     True
# 20                   Gebäudehüllfläche  511.341024   m2     True
# 21                     Gebäudehüllzahl    3.732580   m2     True
# 22                         Glasflächen    5.193670   m2     True
# 23        Aussenwandfläche (exkl. FEA)  363.751324   m2     True
# 24         Bearbeitete Umgebungsfläche  232.368118   m2     True
# 25                  Gebäudegrundfläche   73.794850   m2     True
# 26                          Ist Fläche   40.000000   m2     True
#
#     calculation_time          building  \
# 0           0.002595  Example Building
# 1           0.001868  Example Building
# 2           0.002230  Example Building
# 3           0.001680  Example Building
# 4           0.002747  Example Building
# 5           0.002711  Example Building
# 6           0.002553  Example Building
# 7           0.003261  Example Building
# 8           0.003098  Example Building
# 9           0.001890  Example Building
# 10          0.001830  Example Building
# 11          0.001939  Example Building
# 12          0.003984  Example Building
# 13          0.001336  Example Building
# 14          0.001669  Example Building
# 15          0.002061  Example Building
# 16          0.003060  Example Building
# 17          0.001853  Example Building
# 18          0.001338  Example Building
# 19          0.001434  Example Building
# 20          0.002934  Example Building
# 21          0.008681  Example Building
# 22          0.000929  Example Building
# 23          0.001420  Example Building
# 24          0.001066  Example Building
# 25          0.001618  Example Building
# 26          0.001874  Example Building
#
#                                           description  \
# 0   Die Fläche aller Räume die nach SIA416 als HNF...
# 1   Die Fläche aller Räume die nach SIA416 als NNF...
# 2   Die Fläche aller Räume die nach SIA416 als VF ...
# 3   Die Fläche aller Räume die nach SIA416 als FF ...
# 4   Die Gesamte Geschossfläche, durch die abstract...
# 5                         Der Anteil der KF an der GF
# 6   Die Fläche aller Räume die nach SIA416 als KF ...
# 7                      Die Geschossfläche oberirdisch
# 8                     Die Geschossfläche unterirdisch
# 9                     Das Geschossvolumen oberirdisch
# 10                  Das  Geschossvolumen unterirdisch
# 11  Die Fläche aller Räume (inkl. Wände) die als E...
# 12  Die Fläche aller Räume (inkl. Wände) die als E...
# 13                      Fläche Bodenplatte, Fundament
# 14  Die Fläche der Aussenwand unter Terrain. Decke...
# 15          Die Fläche aller Aussenwände über Terrain
# 16                 Die Fläche aller Fenster und Türen
# 17  Die Fläche aller Untersichten sind. Coverings ...
# 18  Die Fläche aller Dächer. Vorsicht bei Auskragu...
# 19                                Ausengeschossfläche
# 20  Die Fläche aller Aussenwände, Dächer und Boden...
# 21  Die Gebäudehüllzahl ist die Summe der Flächen ...
# 22  Die Fläche aller Glasflächen (Fensterfläche - ...
# 23           Aussenwandfläche exkl. Fenster und Türen
# 24  Die Fläche aller Räume die als BUF klassifizie...
# 25                       Die Grundfläche des Gebäudes
# 26  Die Nutzbare Fläche des Gebäudes nur HHF und N...
#
#                                               formula  \
# 0                                                 HNF
# 1                                                 NNF
# 2                                                  VF
# 3                                                  FF
# 4                                            GF - LUF
# 5                      (GF-net_floor_area) / GF * 100
# 6                                   GF-net_floor_area
# 7                                          GFoi-LUFoi
# 8                                          GFui-LUFui
# 9                                                GVoi
# 10                                               GVui
# 11                                   NNF_UG_gr_als_10
# 12                            GF-NNF_UG_gr_als_10-LUF
# 13                                                FBF
# 14                                                 E1
# 15                                                 E2
# 16                                    Fenster + Türen
# 17                                               E2.5
# 18                                                 DF
# 19                                                AGF
# 20            external_coverings - Balkonuntersichten
# 21  (external_coverings - Balkonuntersichten + Fen...
# 22                 Glasflächen - (Glasflächen * 0.15)
# 23                                                AWF
# 24                                                BUF
# 25                                                GGF
# 26                                              Ist_A
#
#                                            components
# 0   [{'HNF': {'filter': 'IfcEntity=IfcSpace AND Pr...
# 1   [{'NNF': {'filter': 'IfcEntity=IfcSpace AND Pr...
# 2   [{'VF': {'filter': 'IfcEntity=IfcSpace AND Pre...
# 3   [{'FF': {'filter': 'IfcEntity=IfcSpace AND Pre...
# 4   [{'GF': {'filter': 'IfcEntity=IfcSpace AND Nam...
# 5   [{'GF': {'filter': 'IfcEntity=IfcSpace AND Nam...
# 6   [{'GF': {'filter': 'IfcEntity=IfcSpace AND Nam...
# 7   [{'GFoi': {'filter': 'IfcEntity=IfcSpace AND N...
# 8   [{'GFui': {'filter': 'IfcEntity=IfcSpace AND N...
# 9   [{'GVoi': {'filter': 'IfcEntity=IfcSpace AND N...
# 10  [{'GVui': {'filter': 'IfcEntity=IfcSpace AND N...
# 11  [{'NNF_UG_gr_als_10': {'filter': 'IfcEntity=If...
# 12  [{'NNF_UG_gr_als_10': {'filter': 'IfcEntity=If...
# 13  [{'FBF': {'filter': 'IfcEntity=IfcSlab AND Pre...
# 14  [{'E1': {'filter': 'IfcEntity=IfcCovering AND ...
# 15  [{'E2': {'filter': 'IfcEntity=IfcCovering AND ...
# 16  [{'Fenster': {'filter': 'IfcEntity=IfcWindow A...
# 17  [{'E2.5': {'filter': 'IfcEntity=IfcCovering AN...
# 18  [{'DF': {'filter': 'IfcEntity=IfcCovering AND ...
# 19  [{'AGF': {'filter': 'IfcEntity=IfcSpace AND Pr...
# 20  [{'external_coverings': {'filter': 'IfcEntity=...
# 21  [{'external_coverings': {'filter': 'IfcEntity=...
# 22  [{'Glasflächen': {'filter': 'IfcEntity=IfcWind...
# 23  [{'AWF': {'filter': 'IfcEntity=IfcCovering AND...
# 24  [{'BUF': {'filter': 'IfcEntity=IfcSpace AND Pr...
# 25  [{'GGF': {'filter': 'IfcEntity=IfcSpace AND Na...
# 26  [{'Ist_A': {'filter': 'IfcEntity=IfcSpace AND ...

# %%
combined_results.to_excel("berechneten_metriken.xlsx")
